# %%
from kiwipiepy import Kiwi
from kiwipiepy.utils import Stopwords
import re
import copy
import pandas as pd
from PIL import Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

kiwi = Kiwi(typos='basic')
stopwords = Stopwords()

# %%
query = "전체"
df = pd.read_csv(f"../Preprocessed_Content/전체/{query}_combined.csv") # 전체
#df = pd.read_csv(f"../Preprocessed_Content/천주교/preprocessed_{query}.csv") # 개별
df
# Out:
#                                                     link  \
# 0      https://n.news.naver.com/mnews/article/469/000...
# 1      https://n.news.naver.com/mnews/article/021/000...
# 2      https://n.news.naver.com/mnews/article/421/000...
# 3      https://n.news.naver.com/mnews/article/032/000...
# 4      https://n.news.naver.com/mnews/article/015/000...
# ...                                                  ...
# 14543  https://n.news.naver.com/mnews/article/021/000...
# 14544  https://n.news.naver.com/mnews/article/032/000...
# 14545  https://n.news.naver.com/mnews/article/087/000...
# 14546  https://n.news.naver.com/mnews/article/056/001...
# 14547  https://n.news.naver.com/mnews/article/008/000...
#
#                                                title  \
# 0                    개신교계, 부활절 연합예배 인원 방역지침의 절반으로 축소
# 1                          개신교, 性소수자 인권활동 목사 이단조사 논란
# 2                [윤석열 당선] 개신교 "갈등과 분열 해결해 국민 통합 이루길"
# 3                     [사유와 성찰]극우 개신교를 보는 청년들의 싸늘한 시선
# 4                "개신교, 배타성의 뿌리 잘라라" .. 한신대 김경재 교수 제시
# ...                                              ...
# 14543        상호 교감 태도, 세계인 거듭나는 첫걸음[김헌·김월회의 고전 매트릭스]
# 14544  “나는 하느님을 위하여 달립니다, 바로 지금” 흑산도 성당 설립 진요한 신부 선종
# 14545                         “하느님 만나는 은총 가득한 곳 되소서”
# 14546              교황, ‘동성 커플 축복’ 공식 승인…“하느님은 모두 환영”
# 14547                                  [청계광장]하느님의 은총
#
#                                                     body  \
# 0      30일 오후 서울 중구 프레스센터에서 열린 '2021 한국교회 부활절연합예배 기자간...
# 1      섬돌향린교회 임보라 목사에예장합동서 자료 요구 공문임목사 “소명의향 전혀 없어”성소...
# 2      윤석열 국민의힘 대선 후보가 2일 서울 서대문구 스위스그랜드호텔 컨벤션센터에서 열린...
# 3      최근 유럽을 휩쓸고 있는 극우주의의 바람이 심상치 않다. 몇몇 나라에서 극우주의 정...
# 4      "기독교방송(CBS)이나 기독교TV에 스님이 출연해 불교를 소개하고 불교방송이나 불...
# ...                                                  ...
# 14543  게티이미지뱅크(36) 세계인의 날■ 대니얼 디포 ‘로빈슨 크루소’· 미셸 투르니에 ...
# 14544  [경향신문]1955년 아일랜드서 한국 파견전국에 19개 본당·공소 세워한국교회 발전...
# 14545  천주교 원주교구 '기도학교'“하느님 만나는 은총 가득한 곳 되소서” ◇천주교 원주교...
# 14546  교황, ‘동성 커플 축복’ 공식 승인…“하느님은 모두 환영”KBS뉴스재생1,3400...
# 14547  혜원 스님(대한불교조계종 조계사 선감)초등학교 3학년 즈음 12월24일 크리스마스 ...
#
#                                                 pre_body
# 0      오후 서울 중구 프레스센터 한국 교회 부활절 연합 예배 기자 간담회 한국 교회 연합...
# 1      섬돌 향린교회 임보라 목사 장 합동 서 자료 요구 공문 임목 사 소명 의향 성 소수...
# 2      윤석열 국민 힘 대선 후보 서울 서대문구 스위스 그랜드 호텔 컨벤션 센터 대한민국 ...
# 3      최근 유럽 극우 주의 바람 나라 극우 주의 정권 파시즘 시대 부활 현상 중심 청년 ...
# 4      기독교방송 기독교 스님 출연 불교 소개 불교 방송 불교 텔레비젼 신부 목사 출연 기...
# ...                                                  ...
# 14543  게티 이미지 뱅크 세계인 날 대니얼 디포 로빈슨 크루소 미셸 투르니에 방드르디 태평...
# 14544  경향신문 아일랜드 한국 파견 전국 본당 공소 한국 교회 발전 기여 요한 신부 선종 ...
# 14545  천주교 원주 교구 기도 학교 하느님 은총 천주교 원주 교구 교구장 조규만 충북 제천...
# 14546  교황 동성 커플 축복 공식 승인 하느님 환영 뉴스 재생 앵커 동성 커플 가톨릭 교회...
# 14547  혜원 스님 대한불교조계종 조계사 선 감 초등학교 학년 크리스마스 이브 날 요즘 아기...
#
# [14548 rows x 4 columns]

# %%
#추가적인 불용어 처리 (wordcloud 결과를 기준으로 분석에 의미없는 키워드는 불용어 처리)
# 기본 불용어 로드
default_stopwords = Stopwords().stopwords

# 추가적인 사용자 불용어 (WordCloud 보고 점진적으로 업데이트 가능)
custom_stopwords = set([
    '이번', '이후', '가운데', '관련', '최근', '필요', '지금'] 
)

# 기존 불용어와 사용자 불용어 통합
stopwords = set(default_stopwords).union(custom_stopwords)

# %%
all_content = ''.join(df['pre_body'])
len(all_content)
# Out:
# 9916753

# %%
#단어별 출현 빈도수 비율로 출력
wc = WordCloud().generate(all_content)
for word, freq in wc.words_.items():
    print(f"'{word}': {freq}")
# Out:
# '생각': 1.0
# '전': 0.8587191691908265
# '시작': 0.7825616616183471
# '자신': 0.7472955430549546
# '모습': 0.7323669407183038
# '당시': 0.7172219818260493
# '한국 교회': 0.6882302033751623
# '교회': 0.6538295110341843
# '프란치스코 교황': 0.6306793595845954
# '이야기': 0.6233232366940719
# '이후': 0.574643011683254
# '자리': 0.5607961921246214
# '길': 0.5562527044569451
# '가운데': 0.5173085244482908
# '이유': 0.5114668974469927
# '설명': 0.5106014712245781
# '종교': 0.49718736477715275
# '지금': 0.48853310255300736
# '정도': 0.4883167459974037
# '마음': 0.47749891821722196
# '부처 날': 0.47295543054954564
# '의미': 0.468628299437473
# '기도': 0.46062310688013847
# '김 여사': 0.4482907832107313
# '뜻': 0.4452617914322804
# '주장': 0.43617481609692776
# '세계': 0.4324967546516659
# '윤 대통령': 0.43141497187364775
# '세상': 0.42881869320640414
# '현지 시간': 0.4234097793163133
# '존재': 0.22003461704889657
# '한국 기독교': 0.21981826049329295
# '국가': 0.21895283427087842
# '확인': 0.21787105149286023
# '평가': 0.21678926871484205
# '기자 회견': 0.21614019904803117
# '전시': 0.21570748593682387
# '땅': 0.21549112938122025
# '교회 목사': 0.21138035482475118
# '지원': 0.2109476417135439
# '경험': 0.2107312851579403
# '마을': 0.2107312851579403
# '한국': 0.21008221549112938
# '선': 0.2083513630463003
# '예수 그리스도': 0.20813500649069666
# '김대건 신부': 0.20791864993509304
# '현장': 0.20748593682388577
# '주교 회의': 0.20726958026828213
# '시민': 0.20553872782345306
# '오후 서울': 0.2053223712678494
# '결정': 0.2040242319342276
# '그림': 0.20294244915620943
# '주변': 0.20186066637819125
# '차례': 0.20164430982258763
# '성 베드로': 0.19948074426655127
# '주민': 0.19926438771094765
# '물': 0.19861531804413673
# '건물': 0.19861531804413673
# '이해': 0.19796624837732582
# '진우 스님': 0.19731717871051493
# '대신': 0.19666810904370402
# '인도': 0.1964517524881004
# '기억': 0.1960190393768931
# '어머니': 0.1958026828212895
# '상태': 0.19536996971008222
# '과거': 0.19493725659887495
# '정 추기경': 0.19428818693206404
# '서울 중구': 0.1934227607096495
# '끝': 0.19320640415404586
# '방문': 0.19234097793163132
# '시기': 0.1914755517092168
# '교육': 0.19082648204240588
# '주제': 0.19061012548680226
# '운영': 0.1903937689311986
# '명품 가방': 0.190177412375595
# '위': 0.18758113370835136
# '국내': 0.1871484205971441
# '친구': 0.1871484205971441
# '오전 서울': 0.18649935093033318
# '배': 0.1860666378191259
# '천주교 주교': 0.18541756815231503
# '몸': 0.18520121159671138
# '자체': 0.18433578537429685
# '현실': 0.1841194288186932
# '기독교인': 0.18303764604067504
# '개신교': 0.1828212894850714
# '마지막': 0.18217221981826048
# '왼쪽': 0.18173950670705322
# '답': 0.18130679359584595
# '기대': 0.18044136737343142
# '서울 소리': 0.18022501081782777
# '대상': 0.17957594115101688
# '부산': 0.17935958459541324
# '해당': 0.17935958459541324
# '아버지': 0.17914322803980962
# '승려 대회': 0.17914322803980962
# '규모': 0.17741237559498052
# '인생': 0.17676330592816963
# '영향': 0.17633059281696237
# '개인': 0.17589787970575507
# '방법': 0.17524881003894419
# '행동': 0.1735179575941151
# '공개': 0.17330160103851147
# '거리': 0.1728688879273042
# '요구': 0.1728688879273042
# '사역': 0.1728688879273042
# '천주교 서울': 0.17243617481609694

# %%
font_path = 'C:\\Users\\user\\anaconda3\\envs\\kiwi\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\malgun.ttf'
cloud = WordCloud(font_path=font_path,
                  background_color = 'white', 
                  width=800, height=800,
                  colormap='viridis'			
                  )
my_cloud1 = cloud.generate_from_text(all_content)

arr1 = my_cloud1.to_array()

fig = plt.figure(figsize=(10, 10))
plt.imshow(arr1)
plt.axis('off')
plt.show()
fig.savefig(f'{query}wordcloud_.png') #생성한 그림 저장하기
